# %%
import grblogtools as glt

# %%
summary, timelines, rootlp = glt.get_dataframe(["res1paper.txt", "res2paper.txt", "res1lazy.txt", "res2lazy.txt"], timelines=True)

# %%
timelines
# Out:
#       CurrentNode  RemainingNodes       Obj  Depth  IntInf  Incumbent  \
# 0               0             0.0  49.58824    0.0    72.0        2.0
# 1               0             0.0       NaN    NaN     NaN       24.0
# 2               0             0.0  49.33333    0.0    61.0       24.0
# 3               0             0.0  49.33333    0.0    59.0       24.0
# 4               0             0.0  49.33333    0.0    65.0       24.0
# ...           ...             ...       ...    ...     ...        ...
# 2655         1474           503.0  45.76786   11.0   212.0       40.0
# 2656         2434           622.0  43.34033   17.0   176.0       40.0
# 2657         3885           727.0  41.77737   22.0   161.0       40.0
# 2658         6364           646.0  41.19233   17.0   131.0       40.0
# 2659         7930             NaN       NaN    NaN     NaN       40.0
#
#         BestBd      Gap  ItPerNode   Time  NewSolution        Log  \
# ...

# %%
glt.plot(timelines[timelines['Log'] == 'res2paper'], x="Time", y="Incumbent", color="Log", type="line")
# Out:
# interactive(children=(Dropdown(description='x', index=9, options=('CurrentNode', 'RemainingNodes', 'Obj', 'Dep…

# %%
timelines.to_csv('logs.csv')
